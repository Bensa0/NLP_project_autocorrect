# %%
words_list = []
with open("2of12id.txt", "r") as f:
    for line in f:
        # Remove leading/trailing whitespaces
        line = line.strip()
        
        # Split the line into words
        words = line.split()
        
        # Keep only the words that are alphabetic
        alpha_words = [w.lower() for w in words if w.isalpha() and len(w) > 1]
        
        # Add the alpha words to the list
        words_list.append(alpha_words)
        
print(words_list)
# Out:
# [['aardvark', 'aardvarks'], ['aback'], ['abacus', 'abacuses'], ['abaft'], ['abalone', 'abalones'], ['abandon', 'abandoned', 'abandoning', 'abandons'], ['abandonment'], ['abase', 'abased', 'abasing', 'abases'], ['abasement'], ['abash', 'abashed', 'abashing', 'abashes'], ['abashedly'], ['abashment'], ['abate', 'abated', 'abating', 'abates'], ['abatement'], ['abattoir', 'abattoirs'], ['abbe', 'abbes'], ['abbess', 'abbesses'], ['abbey', 'abbeys'], ['abbot', 'abbots'], ['abbreviate', 'abbreviated', 'abbreviating', 'abbreviates'], ['abbreviation', 'abbreviations'], ['abdicate', 'abdicated', 'abdicating', 'abdicates'], ['abdication', 'abdications'], ['abdomen', 'abdomens'], ['abdominal'], ['abdominals'], ['abduct', 'abducted', 'abducting', 'abducts'], ['abductees'], ['abduction', 'abductions'], ['abductor', 'abductors'], ['abeam'], ['abed'], ['aberrant'], ['aberrants'], ['aberration', 'aberrations'], ['aberrational'], ['abet', 'abetted', 'abetting', 'abets'], ['abetter', 'abetters'], ['abettor', 'abettors'], ['abeyance'], ['abhor', 'abhorred', 'abhorring', 'abhors'], ['abhorrence'], ['abhorrent'], ['abhorrently'], ['abidance'], ['abide', 'abode', 'abiding', 'abides'], ['abidingly'], ['ability', 'abilities'], ['abject'], ['abjection'], ['abjectly'], ['abjectness'], ['abjuration', 'abjurations'], ['abjuratory'], ['abjure', 'abjured', 'abjuring', 'abjures'], ['abjurer', 'abjurers'], ['ablate', 'ablated', 'ablating', 'ablates'], ['ablation', 'ablations'], ['ablative'], ['ablative', 'ablatives'], ['ablaze'], ['able', 'abler', 'ablest'], ['abloom'], ['ablution', 'ablutions'], ['ably'], ['abnegate', 'abnegated', 'abnegating', 'abnegates'], ['abnegation'], ['abnormal'], ['abnormals'], ['abnormality', 'abnormalities'], ['abnormally'], ['aboard'], ['aboard'], ['abode', 'abodes'], ['abolish', 'abolished', 'abolishing', 'abolishes'], ['abolition'], ['abolitionism'], ['abolitionist', 'abolitionists'], ['abominable'], ['abominably'], ['abominate', 'abominated', 'abominating', 'abominates'], ['abomination', 'abominations'], ['aboriginal'], ['aboriginal', 'aboriginals'], ['aborigine', 'aborigines'], ['aborning'], ['abort', 'aborted', 'aborting', 'aborts'], ['abortion', 'abortions'], ['abortionist', 'abortionists'], ['abortive'], ['abortively'], ['abound', 'abounded', 'abounding', 'abounds'], ['about'], ['about'], ['above'], ['above'], ['above'], ['aboveboard'], ['abracadabra'], ['abrade', 'abraded', 'abrading', 'abrades'], ['abrasion', 'abrasions'], ['abrasive'], ['abrasive', 'abrasives'], ['abrasively'], ['abrasiveness'], ['abreast'], ['abridge', 'abridged', 'abridging', 'abridges'], ['abridgement', 'abridgements'], ['abridgment', 'abridgments'], ['abroad'], ['abrogate', 'abrogated', 'abrogating', 'abrogates'], ['abrogation', 'abrogations'], ['abrogator', 'abrogators'], ['abrupt', 'abrupter', 'abruptest'], ['abruptly'], ['abruptness'], ['abs'], ['abscess', 'abscesses'], ['abscess', 'abscessed', 'abscessing', 'abscesses'], ['abscissa', 'abscissas'], ['abscission'], ['abscond', 'absconded', 'absconding', 'absconds'], ['absconder', 'absconders'], ['abseil', 'abseils'], ['abseil', 'abseiled', 'abseiling', 'abseils'], ['absence', 'absences'], ['absent'], ['absent', 'absented', 'absenting', 'absents'], ['absentee', 'absentees'], ['absenteeism'], ['absently'], ['absentminded'], ['absentmindedly'], ['absentmindedness'], ['absinth'], ['absinthe'], ['absolute', 'absolutest'], ['absolute', 'absolutes'], ['absolutely'], ['absoluteness'], ['absolution'], ['absolutism'], ['absolutist'], ['absolutist', 'absolutists'], ['absolve', 'absolved', 'absolving', 'absolves'], ['absorb', 'absorbed', 'absorbing', 'absorbs'], ['absorbency'], ['absorbent'], ['absorbent', 'absorbents'], ['absorbingly'], ['absorption'], ['absorptive'], ['abstain', 'abstained', 'abstaining', 'abstains'], ['abstainer', 'abstainers'], ['abstemious'], ['abstemiously'], ['abstemiousness'], ['abstention', 'abstentions'], ['abstinence'], ['abstinent'], ['abstract'], ['abstract', 'abstracts'], ['abstra ...

# %%
with open("2of12id.txt", "r") as f:
    text = f.read()

# %%
corpus = '''The quick brown fox jumps over the lazy dog. The dog barks at the mailman who is delivering a package. The package contains a new book, which the dog's owner will read. She loves to read books about history, especially the American Revolution. In fact, she is planning a trip to visit some historical sites next month. She will travel to Philadelphia, where she will see Independence Hall and the Liberty Bell. She will also visit Boston, where she will walk the Freedom Trail and see the Old North Church. It will be an exciting trip full of history and adventure!
'''
import nltk
from nltk import word_tokenize


# Tokenize the corpus into sentences
sentences = nltk.sent_tokenize(corpus)

# Initialize an empty list to store bi-words
bi_words_list = []
# Tokenize the corpus into sentences and words
sentences = nltk.sent_tokenize(corpus)
words = [nltk.word_tokenize(sentence) for sentence in sentences]

# Create a list of bi-words
bi_words = [[words[i][j], words[i][j+1]] for i in range(len(words)) for j in range(len(words[i])-1)]

print(bi_words)
# Out:
# [['The', 'quick'], ['quick', 'brown'], ['brown', 'fox'], ['fox', 'jumps'], ['jumps', 'over'], ['over', 'the'], ['the', 'lazy'], ['lazy', 'dog'], ['dog', '.'], ['The', 'dog'], ['dog', 'barks'], ['barks', 'at'], ['at', 'the'], ['the', 'mailman'], ['mailman', 'who'], ['who', 'is'], ['is', 'delivering'], ['delivering', 'a'], ['a', 'package'], ['package', '.'], ['The', 'package'], ['package', 'contains'], ['contains', 'a'], ['a', 'new'], ['new', 'book'], ['book', ','], [',', 'which'], ['which', 'the'], ['the', 'dog'], ['dog', "'s"], ["'s", 'owner'], ['owner', 'will'], ['will', 'read'], ['read', '.'], ['She', 'loves'], ['loves', 'to'], ['to', 'read'], ['read', 'books'], ['books', 'about'], ['about', 'history'], ['history', ','], [',', 'especially'], ['especially', 'the'], ['the', 'American'], ['American', 'Revolution'], ['Revolution', '.'], ['In', 'fact'], ['fact', ','], [',', 'she'], ['she', 'is'], ['is', 'planning'], ['planning', 'a'], ['a', 'trip'], ['trip', 'to'], ['to', 'visit'], ['visit', 'some'], ['some', 'historical'], ['historical', 'sites'], ['sites', 'next'], ['next', 'month'], ['month', '.'], ['She', 'will'], ['will', 'travel'], ['travel', 'to'], ['to', 'Philadelphia'], ['Philadelphia', ','], [',', 'where'], ['where', 'she'], ['she', 'will'], ['will', 'see'], ['see', 'Independence'], ['Independence', 'Hall'], ['Hall', 'and'], ['and', 'the'], ['the', 'Liberty'], ['Liberty', 'Bell'], ['Bell', '.'], ['She', 'will'], ['will', 'also'], ['also', 'visit'], ['visit', 'Boston'], ['Boston', ','], [',', 'where'], ['where', 'she'], ['she', 'will'], ['will', 'walk'], ['walk', 'the'], ['the', 'Freedom'], ['Freedom', 'Trail'], ['Trail', 'and'], ['and', 'see'], ['see', 'the'], ['the', 'Old'], ['Old', 'North'], ['North', 'Church'], ['Church', '.'], ['It', 'will'], ['will', 'be'], ['be', 'an'], ['an', 'exciting'], ['exciting', 'trip'], ['trip', 'full'], ['full', 'of'], ['of', 'history'], ['history', 'and'], ['and', 'adventure'], ['adventure', '!']]

# %%
bi_words
# Out:
# [['The', 'quick'],
#  ['quick', 'brown'],
#  ['brown', 'fox'],
#  ['fox', 'jumps'],
#  ['jumps', 'over'],
#  ['over', 'the'],
#  ['the', 'lazy'],
#  ['lazy', 'dog'],
#  ['dog', '.'],
#  ['The', 'dog'],
#  ['dog', 'barks'],
#  ['barks', 'at'],
#  ['at', 'the'],
#  ['the', 'mailman'],
#  ['mailman', 'who'],
#  ['who', 'is'],
#  ['is', 'delivering'],
#  ['delivering', 'a'],
#  ['a', 'package'],
#  ['package', '.'],
#  ['The', 'package'],
#  ['package', 'contains'],
#  ['contains', 'a'],
#  ['a', 'new'],
#  ['new', 'book'],
#  ['book', ','],
#  [',', 'which'],
#  ['which', 'the'],
#  ['the', 'dog'],
#  ['dog', "'s"],
#  ["'s", 'owner'],
#  ['owner', 'will'],
#  ['will', 'read'],
#  ['read', '.'],
#  ['She', 'loves'],
#  ['loves', 'to'],
#  ['to', 'read'],
#  ['read', 'books'],
#  ['books', 'about'],
#  ['about', 'history'],
#  ['history', ','],
#  [',', 'especially'],
#  ['especially', 'the'],
#  ['the', 'American'],
#  ['American', 'Revolution'],
#  ['Revolution', '.'],
#  ['In', 'fact'],
#  ['fact', ','],
#  [',', 'she'],
#  ['she', 'is'],
#  ['is', 'planning'],
#  ['planning', 'a'],
#  ['a', 'trip'],
#  ['trip', 'to'],
#  ['to', 'visit'],
#  ['visit', 'some'],
#  ['some', 'historical'],
#  ['historical', 'sites'],
#  ['sites', 'next'],
#  ['next', 'month'],
#  ['month', '.'],
#  ['She', 'will'],
#  ['will', 'travel'],
#  ['travel', 'to'],
#  ['to', 'Philadelphia'],
#  ['Philadelphia', ','],
#  [',', 'where'],
#  ['where', 'she'],
#  ['she', 'will'],
#  ['will', 'see'],
#  ['see', 'Independence'],
#  ['Independence', 'Hall'],
#  ['Hall', 'and'],
#  ['and', 'the'],
#  ['the', 'Liberty'],
#  ['Liberty', 'Bell'],
#  ['Bell', '.'],
#  ['She', 'will'],
#  ['will', 'also'],
#  ['also', 'visit'],
#  ['visit', 'Boston'],
#  ['Boston', ','],
#  [',', 'where'],
#  ['where', 'she'],
#  ['she', 'will'],
#  ['will', 'walk'],
#  ['walk', 'the'],
#  ['the', 'Freedom'],
#  ['Freedom', 'Trail'],
#  ['Trail', 'and'],
#  ['and', 'see'],
#  ['see', 'the'],
#  ['the', 'Old'],
#  ['Old', 'North'],
#  ['North', 'Church'],
#  ['Church', '.'],
#  ['It', 'will'],
#  ['will', 'be'],
#  ['be', 'an'],
#  ['an', 'exciting'],
#  ['exciting', 'trip'],
#  ['trip', 'full'],
#  ['full', 'of'],
#  ['of', 'history'],
#  ['history', 'and'],
#  ['and', 'adventure'],
#  ['adventure', '!']]

# %%
from gensim.models import FastText

# Train FastText on your corpus
fasttext_model = FastText(words_list, vector_size=100, window=5, min_count=1, workers=4, sg=1)

# %%
from gensim.models import FastText

def autocorrect(text, fasttext_model):
    # Tokenize the text
    tokens = text.split()

    # Initialize an empty list to store corrected tokens
    corrected_tokens = []

    # Loop through the tokens
    for token in tokens:
        # Check if the token is in the FastText vocabulary
        if token in fasttext_model.wv.key_to_index:
            corrected_tokens.append(token)
        else:
            # If token is not in the vocabulary, get the embedding from FastText
            embedding = fasttext_model.wv[token]
            # Find the most similar word to the OOV token
            similar_word = fasttext_model.wv.similar_by_vector(embedding)[0][0]
            corrected_tokens.append(similar_word)

    # Join the corrected tokens back into a sentence
    corrected_text = ' '.join(corrected_tokens)

    return corrected_text

# %%
from gensim.models import FastText

def autocorrect(text, fasttext_model):
    # Tokenize the text
    tokens = text.split()

    # Initialize an empty list to store corrected tokens
    corrected_tokens = []

    # Loop through the tokens
    for token in tokens:
        # If token is not in the vocabulary, get the embedding from FastText
        embedding = fasttext_model.wv[token]
        # Find the most similar word to the OOV token
        similar_word = fasttext_model.wv.similar_by_vector(embedding)[0][0]
        corrected_tokens.append(similar_word)

    # Join the corrected tokens back into a sentence
    corrected_text = ' '.join(corrected_tokens)

    return corrected_text

# %%
# Test the autocorrect function
text = "ana app orgg"
corrected_text = autocorrect(text, fasttext_model)
print(corrected_text)
# Out:
# anbana appaya rneoag

# %%
from gensim.models import FastText

# Create a list of lists for training FastText
train_corpus = []
for words in corpus:
    train_corpus.append(words)

# Train FastText on the training corpus
fasttext_model = FastText(train_corpus, vector_size=100, window=5, min_count=1, workers=4, sg=1)

# Function for autocorrection
def autocorrect(word, model):
    if word in model.wv:
        return word
    else:
        similar_words = model.wv.most_similar(word)
        return similar_words[0][0]

# %%
# Example usage of autocorrect function
misspelled_word = 'aple'
corrected_word = autocorrect(misspelled_word, fasttext_model)
print(f"Did you mean '{corrected_word}'?")
# Out:
# Did you mean 'aple'?

# %%
import random

# function to create misspelled versions of a word
def create_misspelled(word):
    # create a list to store the misspelled versions
    misspelled_list = []
    
    # add different types of errors to the list
    # missing letters
    for i in range(len(word)):
        misspelled = word[:i] + word[i+1:]
        misspelled_list.append(misspelled)
    
    # repeated letters
    for i in range(len(word)):
        misspelled = word[:i] + word[i] + word[i:]
        misspelled_list.append(misspelled)
        
    # swapped adjacent letters
    for i in range(len(word)-1):
        misspelled = word[:i] + word[i+1] + word[i] + word[i+2:]
        misspelled_list.append(misspelled)
    
    # replace letters with random letters
    for i in range(len(word)):
        misspelled = word[:i] + random.choice('abcdefghijklmnopqrstuvwxyz') + word[i+1:]
        misspelled_list.append(misspelled)
    
    return misspelled_list

# example corpus
corpus = ['apple', 'banana', 'cherry', 'dog', 'elephant', 'frog']

# create dictionary of misspelled words
misspelled_dict = {}
for word in corpus:
    misspelled_dict[word] = create_misspelled(word)

# %%
misspelled_dict
# Out:
# {'apple': ['pple',
#   'aple',
#   'aple',
#   'appe',
#   'appl',
#   'aapple',
#   'appple',
#   'appple',
#   'applle',
#   'applee',
#   'paple',
#   'apple',
#   'aplpe',
#   'appel',
#   'qpple',
#   'ayple',
#   'apmle',
#   'appbe',
#   'applk'],
#  'banana': ['anana',
#   'bnana',
#   'baana',
#   'banna',
#   'banaa',
#   'banan',
#   'bbanana',
#   'baanana',
#   'bannana',
#   'banaana',
#   'bananna',
#   'bananaa',
#   'abnana',
#   'bnaana',
#   'baanna',
#   'bannaa',
#   'banaan',
#   'ganana',
#   'blnana',
#   'basana',
#   'bantna',
#   'banaza',
#   'bananj'],
#  'cherry': ['herry',
#   'cerry',
#   'chrry',
#   'chery',
#   'chery',
#   'cherr',
#   'ccherry',
#   'chherry',
#   'cheerry',
#   'cherrry',
#   'cherrry',
#   'cherryy',
#   'hcerry',
#   'cehrry',
#   'chrery',
#   'cherry',
#   'cheryr',
#   'pherry',
#   'cxerry',
#   'chmrry',
#   'cheery',
#   'chercy',
#   'cherrj'],
#  'dog': ['og',
#   'dg',
#   'do',
#   'ddog',
#   'doog',
#   'dogg',
#   'odg',
#   'dgo',
#   'uog',
#   'dgg',
#   'doe'],
#  'elephant': ['lephant',
#   'eephant',
#   'elphant',
#   'elehant',
#   'elepant',
#   'elephnt',
#   'elephat',
#   'elephan',
#   'eelephant',
#   'ellephant',
#   'eleephant',
#   'elepphant',
#   'elephhant',
#   'elephaant',
#   'elephannt',
#   'elephantt',
#   'leephant',
#   'eelphant',
#   'elpehant',
#   'elehpant',
#   'elepahnt',
#   'elephnat',
#   'elephatn',
#   'qlephant',
#   'epephant',
#   'ellphant',
#   'elexhant',
#   'elepyant',
#   'elephpnt',
#   'elephawt',
#   'elephanq'],
#  'frog': ['rog',
#   'fog',
#   'frg',
#   'fro',
#   'ffrog',
#   'frrog',
#   'froog',
#   'frogg',
#   'rfog',
#   'forg',
#   'frgo',
#   'hrog',
#   'fkog',
#   'frvg',
#   'froz']}

# %%
from gensim.models.fasttext import FastText

# Flatten the corpus and create a list of sentences
sentences = []
for key, misspellings in misspelled_dict.items():
    for misspelling in misspellings:
        sentences.append([misspelling, key])

# Train a FastText model on the sentences
model = FastText(sentences=sentences, vector_size=100, window=5, min_count=1, sg=1)

# %%
# Correct a misspelled word
misspelled_word = 'aple'
corrected_word = model.wv.most_similar(misspelled_word, topn=1)[0][0]

print(f"Misspelled word: {misspelled_word}")
print(f"Corrected word: {corrected_word}")
# Out:
# Misspelled word: aple
# Corrected word: paple

# %%
# Import FastText module from gensim package
from gensim.models import FastText

# Build vocabulary from words_list
model = FastText(vector_size=100, window=5, min_count=1)
model.build_vocab(corpus_iterable=words_list)

# Train FastText model on words_list
model.train(corpus_iterable=words_list, total_examples=len(words_list), epochs=10)

# Get most similar words
similar_words = model.wv.most_similar('werwaw')
print(similar_words)
# Out:
# [('pepla', 0.27258211374282837), ('rpae', 0.24975909292697906), ('iiwk', 0.22473536431789398), ('apreg', 0.22198528051376343), ('chepa', 0.2203996628522873), ('aogren', 0.22001056373119354), ('pinepepla', 0.2078191339969635), ('eppal', 0.20411817729473114), ('eoargn', 0.19019654393196106), ('nipeplpae', 0.18879777193069458)]

# %%
import random

# Define the list of fruits
fruits = ['apple', 'banana', 'orange', 'kiwi', 'mango', 'papaya', 'pineapple', 'grape', 'pear', 'peach']

# Define a function to generate misspelled words
def generate_misspelled(word):
    # Split the word into characters
    chars = list(word)
    # Shuffle the characters
    random.shuffle(chars)
    # Join the shuffled characters back into a string
    misspelled = ''.join(chars)
    # Return the misspelled word
    return misspelled

# Create a list of lists to hold the words and their misspellings
words_list = [[word] + [generate_misspelled(word) for i in range(100)] for word in fruits]
words_list
# Out:
# [['apple',
#   'elapp',
#   'eppla',
#   'plepa',
#   'eppla',
#   'pplae',
#   'laepp',
#   'lpape',
#   'palpe',
#   'aeplp',
#   'lpape',
#   'apepl',
#   'pplae',
#   'papel',
#   'lppea',
#   'pealp',
#   'ppela',
#   'eppal',
#   'apple',
#   'apepl',
#   'paelp',
#   'eplap',
#   'eappl',
#   'lppea',
#   'epapl',
#   'epapl',
#   'paple',
#   'leapp',
#   'leapp',
#   'eappl',
#   'ealpp',
#   'ppeal',
#   'palpe',
#   'aplep',
#   'lpeap',
#   'pplae',
#   'lpaep',
#   'alpep',
#   'lppae',
#   'ppela',
#   'pepal',
#   'paple',
#   'apepl',
#   'lppea',
#   'pepal',
#   'apepl',
#   'elpap',
#   'elppa',
#   'paepl',
#   'lpape',
#   'lppae',
#   'leapp',
#   'appel',
#   'epalp',
#   'plaep',
#   'lappe',
#   'ppeal',
#   'eppal',
#   'elpap',
#   'apelp',
#   'alppe',
#   'plpae',
#   'lapep',
#   'paepl',
#   'ppeal',
#   'leppa',
#   'ppela',
#   'plepa',
#   'plaep',
#   'elpap',
#   'lpaep',
#   'aeppl',
#   'palep',
#   'elppa',
#   'eaplp',
#   'pelap',
#   'lepap',
#   'eppla',
#   'pplae',
#   'pepla',
#   'epapl',
#   'eaplp',
#   'plpea',
#   'aelpp',
#   'palpe',
#   'lpaep',
#   'lppae',
#   'leppa',
#   'plaep',
#   'lpaep',
#   'epapl',
#   'leppa',
#   'lepap',
#   'leapp',
#   'ppela',
#   'alppe',
#   'ppela',
#   'aplep',
#   'epapl',
#   'plpea',
#   'plape'],
#  ['banana',
#   'nanaab',
#   'naanab',
#   'baanna',
#   'aannba',
#   'bnnaaa',
#   'aaanbn',
#   'banaan',
#   'baanna',
#   'nnbaaa',
#   'nanaab',
#   'anbana',
#   'abanna',
#   'anbnaa',
#   'nabaan',
#   'annbaa',
#   'annaba',
#   'aabnna',
#   'bannaa',
#   'abaann',
#   'nnaaab',
#   'nabana',
#   'nanaab',
#   'baanna',
#   'annaba',
#   'nanaab',
#   'abnana',
#   'aananb',
#   'nbaana',
#   'naanab',
#   'nnaaba',
#   'nnaaba',
#   'aaabnn',
#   'nanaba',
#   'ananba',
#   'bannaa',
#   'ananab',
#   'naanab',
#   'nbanaa',
#   'naanab',
#   'bnnaaa',
#   'aanbna',
#   'naabna',
#   'abnaan',
#   'aanbna',
#   'naanba',
#   'ananab',
#   'aannba',
#   'ananab',
#   'ananba',
#   'bnnaaa',
#   'abnnaa',
#   'naanba',
#   'nnaaab',
#   'naaban',
#   'abnaan',
#   'aabann',
#   'nnaaba',
#   'nabnaa',
#   'annaab',
#   'naaabn',
#   'nabaan',
#   'anaban',
#   'naaabn',
#   'nanaab',
#   'baanan',
#   'naaban',
#   'baaann',
#   'aanabn',
#   'bnanaa',
#   'aanban',
#   'annbaa',
#   'anbnaa',
#   'naanab',
#   'aabnna',
#   'naanab',
#   'banaan',
#   'annaba',
#   'nnaaab',
#   'nabana',
#   'abnnaa',
#   'nbaaan',
#   'nanbaa',
#   'banana',
#   'annaba',
#   'nbaana',
#   'banaan',
#   'aaannb',
#   'aaannb',
#   'abanan',
#   'anbaan',
#   'anbnaa',
#   'abnana',
#   'banaan',
#   'nbaaan',
#   'aaanbn',
#   'banana',
#   'nnaaab',
#   'anbana',
#   'baaann',
#   'nanaba'],
#  ['orange',
#   'rneago',
#   'areong',
#   'gornae',
#   'gnaeor',
#   'egoanr',
#   'nogear',
#   'rgeano',
#   'ognear',
#   'eorgna',
#   'agreon',
#   'rogane',
#   'ngreoa',
#   'eoangr',
#   'aoergn',
#   'ageonr',
#   'eorgan',
#   'aonger',
#   'rogaen',
#   'gonear',
#   'naergo',
#   'ageorn',
#   'reagno',
#   'aegorn',
#   'gaorne',
#   'eogarn',
#   'ograne',
#   'rengao',
#   'ranoge',
#   'agreon',
#   'oneagr',
#   'arengo',
#   'roegna',
#   'gonrea',
#   'ergano',
#   'agnero',
#   'oreagn',
#   'aoenrg',
#   'oengar',
#   'gnearo',
#   'onerga',
#   'naeogr',
#   'aoegrn',
#   'eogarn',
#   'angreo',
#   'aogner',
#   'aoerng',
#   'rgoena',
#   'reonag',
#   'aernog',
#   'aenogr',
#   'onareg',
#   'roagne',
#   'arneog',
#   'ngroea',
#   'ngaroe',
#   'aeongr',
#   'aregon',
#   'orange',
#   'angero',
#   'grnaeo',
#   'ogaern',
#   'eanorg',
#   'negaro',
#   'oernag',
#   'orneag',
#   'agnore',
#   'regoan',
#   'rgonea',
#   'eoagrn',
#   'nrgaeo',
#   'aeongr',
#   'onaegr',
#   'agroen',
#   'rogean',
#   'noegra',
#   'nogrea',
#   'rnegao',
#   'ngreao',
#   'eaonrg',
#   'oernag',
#   'nrgoae',
#   'eognra',
#   'eaorgn',
#   'gneroa',
#   'angoer',
#   'goeanr',
#   'eoagrn',
#   'oaengr',
#   'gonera',
#   'aonegr',
#   'oanger',
#   'grnoea',
#   'ergnoa',
#   'oegrna',
#   'gerona',
#   'ogerna',
#   'oagner',
#   'rnaoeg',
#   'eganro',
#   'ngorae'],
#  ['kiwi',
#   'kwii',
#   'wkii',
#   'kiiw',
#   'kiwi',
#   'kiwi',
#   'iwki',
#   'ikiw',
#   'kiiw',
#   'wiik',
#   'kwii',
#   'wiki',
#   'wiki',
#   'iwik',
#   'iikw',
#   'wkii',
#   'wiki',
#   'iwki',
#   'wkii',
#   'kiiw',
#   'kwii',
#   'wiik',
#   'wiik',
#   'kwii',
#   'wkii',
#   'iikw',
#   'wkii',
#   'iwik',
#   'iwik',
#   'wiik',
#   'wiik',
#   'ikwi',
#   'ikiw',
#   'iwik',
#   'kiwi',
#   'wiki',
#   'ikiw',
#   'wiik',
#   'wiik',
#   'ikiw',
#   'ikwi',
#   'iiwk',
#   'iwik',
#   'ikwi',
#   'ikiw',
#   'iwki',
#   'wiki',
#   'kiwi',
#   'ikwi',
#   'wiik',
#   'ikiw',
#   'wiik',
#   'kiwi',
#   'ikiw',
#   'wiki',
#   'kiiw',
#   'wkii',
#   'wkii',
#   'ikwi',
#   'kiwi',
#   'iwki',
#   'kiiw',
#   'ikwi',
#   'iiwk',
#   'kwii',
#   'iwik',
#   'iwki',
#   'kiiw',
#   'wiik',
#   'iiwk',
#   'iikw',
#   'wiik',
#   'iiwk',
#   'iikw',
#   'kwii',
#   'iiwk',
#   'iikw',
#   'ikiw',
#   'iwik',
#   'kwii',
#   'iwki',
#   'wkii',
#   'kwii',
#   'iikw',
#   'iikw',
#   'iikw',
#   'iwik',
#   'kiwi',
#   'wkii',
#   'wiki',
#   'kiwi',
#   'kwii',
#   'iwki',
#   'wiik',
#   'kiwi',
#   'kwii',
#   'ikwi',
#   'iwki',
#   'iikw',
#   'wkii',
#   'kwii'],
#  ['mango',
#   'mgona',
#   'ognam',
#   'magno',
#   'mogna',
#   'ogamn',
#   'namog',
#   'naomg',
#   'nomag',
#   'aognm',
#   'ognma',
#   'ngoam',
#   'gaonm',
#   'omagn',
#   'ognma',
#   'oamgn',
#   'gaonm',
#   'ognma',
#   'gmaon',
#   'maong',
#   'angom',
#   'anmgo',
#   'nmgao',
#   'ngamo',
#   'monga',
#   'ngmoa',
#   'omnga',
#   'monag',
#   'aongm',
#   'mogan',
#   'aognm',
#   'agnmo',
#   'gmaon',
#   'ngmoa',
#   'gmona',
#   'agnom',
#   'gmano',
#   'gmnoa',
#   'ongam',
#   'mgona',
#   'mngoa',
#   'magon',
#   'gnamo',
#   'aognm',
#   'nmgoa',
#   'among',
#   'nogma',
#   'namgo',
#   'namog',
#   'amgno',
#   'nmoga',
#   'mnago',
#   'mgano',
#   'gamno',
#   'amgno',
#   'angom',
#   'nmaog',
#   'oangm',
#   'aogmn',
#   'ngmao',
#   'agnmo',
#   'ngmao',
#   'ognma',
#   'anmgo',
#   'agnom',
#   'nogam',
#   'onmag',
#   'mgano',
#   'nomag',
#   'onamg',
#   'gmona',
#   'oamng',
#   'gaonm',
#   'gamon',
#   'manog',
#   'noagm',
#   'ogamn',
#   'monga',
#   'amnog',
#   'gmano',
#   'mgoan',
#   'mgoan',
#   'namgo',
#   'mgona',
#   'mnoag',
#   'oagnm',
#   'gmnoa',
#   'magno',
#   'mngao',
#   'nmgao',
#   'gamno',
#   'monag',
#   'nogam',
#   'gnaom',
#   'goanm',
#   'magon',
#   'mnoga',
#   'angom',
#   'noagm',
#   'gnaom',
#   'gmona'],
#  ['papaya',
#   'ppayaa',
#   'paaayp',
#   'ppyaaa',
#   'apaapy',
#   'apyaap',
#   'apyapa',
#   'yaaapp',
#   'ypaaap',
#   'appaya',
#   'appyaa',
#   'pyapaa',
#   'apaapy',
#   'paaapy',
#   'ppayaa',
#   'appaay',
#   'yppaaa',
#   'aappya',
#   'yapapa',
#   'appaya',
#   'aayapp',
#   'aaypap',
#   'pyaapa',
#   'paypaa',
#   'aypapa',
#   'ppaaya',
#   'apyapa',
#   'ppayaa',
#   'aapyap',
#   'pyapaa',
#   'paaayp',
#   'paypaa',
#   'paapay',
#   'ayaapp',
#   'aapapy',
#   'yaapap',
#   'apaypa',
#   'aaaypp',
#   'paayap',
#   'apaypa',
#   'ypapaa',
#   'ayapap',
#   'ayappa',
#   'ppyaaa',
#   'apayap',
#   'pyaapa',
#   'paaapy',
#   'appaya',
#   'yapapa',
#   'papyaa',
#   'aypapa',
#   'paapay',
#   'aypapa',
#   'aaappy',
#   'apapya',
#   'yaappa',
#   'aapypa',
#   'yaaapp',
#   'aayapp',
#   'papyaa',
#   'aappay',
#   'yppaaa',
#   'appaya',
#   'ypaaap',
#   'ayaapp',
#   'aayapp',
#   'paaapy',
#   'paaayp',
#   'papaya',
#   'paapay',
#   'apaapy',
#   'apaayp',
#   'apyapa',
#   'ayaapp',
#   'pyapaa',
#   'aypapa',
#   'pyapaa',
#   'aaapyp',
#   'apaayp',
#   'aapapy',
#   'aaappy',
#   'ypapaa',
#   'aaapyp',
#   'ypaaap',
#   'ayppaa',
#   'yaapap',
#   'ypaapa',
#   'paaayp',
#   'appaay',
#   'aaappy',
#   'papaay',
#   'appyaa',
#   'ayppaa',
#   'apaayp',
#   'yapaap',
#   'yappaa',
#   'aaapyp',
#   'appyaa',
#   'pyaaap',
#   'pypaaa',
#   'pyapaa'],
#  ['pineapple',
#   'aenppplei',
#   'nplaepeip',
#   'aielenppp',
#   'pleenippa',
#   'nieppelpa',
#   'pneelpaip',
#   'appleepin',
#   'ppaieepnl',
#   'nppilaepe',
#   'enlppiepa',
#   'ppneelapi',
#   'piapleenp',
#   'elnpiaepp',
#   'pplpnieae',
#   'ppepleina',
#   'ineeapplp',
#   'lpnieeppa',
#   'eplainpep',
#   'eippnlpae',
#   'pippnleae',
#   'ppneiapel',
#   'peelpapin',
#   'eapinelpp',
#   'elpeipapn',
#   'pnelpepia',
#   'nlpeppeai',
#   'peiplnpae',
#   'einpelapp',
#   'nappipeel',
#   'pinappeel',
#   'lppnpieae',
#   'eappnpiel',
#   'aipplepen',
#   'epnpapile',
#   'eainppple',
#   'peepiapnl',
#   'napppeeil',
#   'applpeeni',
#   'iaepeplnp',
#   'epaippenl',
#   'apnpeiple',
#   'eepinlapp',
#   'ipnaepepl',
#   'ipplapnee',
#   'lpepeinpa',
#   'palieeppn',
#   'pienplpae',
#   'ppienaelp',
#   'leienpppa',
#   'eepnlippa',
#   'elpiaenpp',
#   'eilpppnae',
#   'lepnappie',
#   'elppnaepi',
#   'ppleneiap',
#   'pleeianpp',
#   'epipnplea',
#   'ilneppeap',
#   'eepaipnpl',
#   'eapenppli',
#   'ineepplap',
#   'napelpiep',
#   'enplpaepi',
#   'pnaepeilp',
#   'ppieeanpl',
#   'elapippne',
#   'eaiepplpn',
#   'neiplappe',
#   'naelipepp',
#   'epplniaep',
#   'eippaepnl',
#   'nppalipee',
#   'napepelip',
#   'eeilanppp',
#   'penpplaie',
#   'paenlippe',
#   'eppnelipa',
#   'nepapelip',
#   'epilnppae',
#   'pipenpeal',
#   'nppeepial',
#   'plpnpeaie',
#   'pinepalep',
#   'papinepel',
#   'pnpleeipa',
#   'npaeplepi',
#   'laenieppp',
#   'lepaneppi',
#   'nleppipae',
#   'ppaeipnle',
#   'ippnpaele',
#   'ileaepnpp',
#   'plinpeepa',
#   'inapleppe',
#   'eaplpinep',
#   'eiplanpep',
#   'piepnplea',
#   'apnplpiee',
#   'plpeinape',
#   'anppeilpe'],
#  ['grape',
#   'gaerp',
#   'eparg',
#   'rpage',
#   'arpge',
#   'pgrae',
#   'repag',
#   'aegrp',
#   'grpae',
#   'pegra',
#   'paerg',
#   'epgra',
#   'eprga',
#   'aegpr',
#   'pagre',
#   'eparg',
#   'gerap',
#   'pegar',
#   'aegpr',
#   'prage',
#   'ergap',
#   'agpre',
#   'aeprg',
#   'ergpa',
#   'parge',
#   'egrap',
#   'graep',
#   'eapgr',
#   'egrap',
#   'agrpe',
#   'gpaer',
#   'prgea',
#   'earpg',
#   'pgera',
#   'eparg',
#   'agepr',
#   'pgaer',
#   'rapeg',
#   'perga',
#   'rpage',
#   'rapge',
#   'rgape',
#   'rgeap',
#   'aepgr',
#   'egarp',
#   'preag',
#   'geapr',
#   'repag',
#   'pgaer',
#   'pgera',
#   'egpar',
#   'rpaeg',
#   'pgrae',
#   'egapr',
#   'earpg',
#   'gapre',
#   'eargp',
#   'pgrea',
#   'reapg',
#   'aperg',
#   'geapr',
#   'pagre',
#   'grpea',
#   'pegar',
#   'rpage',
#   'ergap',
#   'ergpa',
#   'aerpg',
#   'eargp',
#   'eprga',
#   'raegp',
#   'egpra',
#   'aregp',
#   'pgera',
#   'garpe',
#   'aprge',
#   'rgepa',
#   'aperg',
#   'aergp',
#   'pegra',
#   'grpae',
#   'agper',
#   'parge',
#   'aeprg',
#   'prega',
#   'gpaer',
#   'gepra',
#   'egrpa',
#   'regap',
#   'agrpe',
#   'repga',
#   'gearp',
#   'gpear',
#   'epgra',
#   'earpg',
#   'raepg',
#   'reagp',
#   'perag',
#   'pegar',
#   'paegr',
#   'argpe'],
#  ['pear',
#   'prae',
#   'epra',
#   'pera',
#   'rape',
#   'apre',
#   'arpe',
#   'apre',
#   'reap',
#   'eapr',
#   'raep',
#   'aerp',
#   'epar',
#   'arep',
#   'aerp',
#   'rpea',
#   'apre',
#   'repa',
#   'rpae',
#   'prea',
#   'repa',
#   'erap',
#   'epar',
#   'earp',
#   'earp',
#   'eapr',
#   'erap',
#   'rape',
#   'repa',
#   'paer',
#   'erap',
#   'erpa',
#   'repa',
#   'aper',
#   'prea',
#   'prae',
#   'arpe',
#   'epar',
#   'pera',
#   'rape',
#   'epar',
#   'prae',
#   'repa',
#   'rpea',
#   'eapr',
#   'eapr',
#   'erpa',
#   'apre',
#   'prea',
#   'prae',
#   'pear',
#   'rape',
#   'pera',
#   'erap',
#   'pera',
#   'aerp',
#   'aper',
#   'rpea',
#   'erpa',
#   'aper',
#   'aepr',
#   'repa',
#   'arep',
#   'prea',
#   'arpe',
#   'erpa',
#   'prea',
#   'earp',
#   'aepr',
#   'epar',
#   'aerp',
#   'pear',
#   'prae',
#   'paer',
#   'erpa',
#   'aper',
#   'reap',
#   'apre',
#   'earp',
#   'prae',
#   'aepr',
#   'rpea',
#   'paer',
#   'arep',
#   'pear',
#   'erpa',
#   'rpea',
#   'reap',
#   'reap',
#   'prea',
#   'erap',
#   'pera',
#   'paer',
#   'reap',
#   'pera',
#   'arep',
#   'raep',
#   'aper',
#   'pear',
#   'rpea',
#   'repa'],
#  ['peach',
#   'chpae',
#   'chpae',
#   'hcepa',
#   'cehap',
#   'heacp',
#   'hapce',
#   'pecah',
#   'achpe',
#   'hceap',
#   'hacpe',
#   'echap',
#   'phcae',
#   'achep',
#   'ceaph',
#   'cpeah',
#   'eaphc',
#   'cahep',
#   'eaphc',
#   'aephc',
#   'chaep',
#   'aehcp',
#   'apche',
#   'chpea',
#   'hcaep',
#   'caeph',
#   'peahc',
#   'ceahp',
#   'cpaeh',
#   'aphec',
#   'apceh',
#   'hceap',
#   'caeph',
#   'eapch',
#   'acphe',
#   'hpcae',
#   'apceh',
#   'chepa',
#   'aehpc',
#   'eachp',
#   'paech',
#   'capeh',
#   'chaep',
#   'aphce',
#   'heapc',
#   'ceahp',
#   'epcah',
#   'hpcea',
#   'ceaph',
#   'hacep',
#   'apech',
#   'aepch',
#   'ehpca',
#   'pehac',
#   'cphae',
#   'ahecp',
#   'apech',
#   'haecp',
#   'pcaeh',
#   'caehp',
#   'ehacp',
#   'aehpc',
#   'aecph',
#   'eahcp',
#   'pehca',
#   'pceha',
#   'ceahp',
#   'aecph',
#   'aehcp',
#   'aepch',
#   'achep',
#   'echpa',
#   'ahpec',
#   'ehacp',
#   'cehpa',
#   'peach',
#   'heapc',
#   'hacpe',
#   'epach',
#   'chpea',
#   'aepch',
#   'apech',
#   'paehc',
#   'haecp',
#   'pache',
#   'haepc',
#   'hcpae',
#   'peahc',
#   'phcae',
#   'hapce',
#   'ahecp',
#   'echap',
#   'acphe',
#   'aphec',
#   'pahec',
#   'paehc',
#   'paceh',
#   'pahec',
#   'apceh',
#   'cahpe',
#   'cheap']]

# %%
# Import FastText module from gensim package
from gensim.models import FastText

# Create pairs of correct and incorrect words
word_pairs = []
for word_group in words_list:
    for i, correct_word in enumerate(word_group):
        for j, incorrect_word in enumerate(word_group):
            if i != j:
                word_pairs.append([correct_word, incorrect_word])
word_pairs
# Out:
# [['apple', 'elapp'],
#  ['apple', 'eppla'],
#  ['apple', 'plepa'],
#  ['apple', 'eppla'],
#  ['apple', 'pplae'],
#  ['apple', 'laepp'],
#  ['apple', 'lpape'],
#  ['apple', 'palpe'],
#  ['apple', 'aeplp'],
#  ['apple', 'lpape'],
#  ['apple', 'apepl'],
#  ['apple', 'pplae'],
#  ['apple', 'papel'],
#  ['apple', 'lppea'],
#  ['apple', 'pealp'],
#  ['apple', 'ppela'],
#  ['apple', 'eppal'],
#  ['apple', 'apple'],
#  ['apple', 'apepl'],
#  ['apple', 'paelp'],
#  ['apple', 'eplap'],
#  ['apple', 'eappl'],
#  ['apple', 'lppea'],
#  ['apple', 'epapl'],
#  ['apple', 'epapl'],
#  ['apple', 'paple'],
#  ['apple', 'leapp'],
#  ['apple', 'leapp'],
#  ['apple', 'eappl'],
#  ['apple', 'ealpp'],
#  ['apple', 'ppeal'],
#  ['apple', 'palpe'],
#  ['apple', 'aplep'],
#  ['apple', 'lpeap'],
#  ['apple', 'pplae'],
#  ['apple', 'lpaep'],
#  ['apple', 'alpep'],
#  ['apple', 'lppae'],
#  ['apple', 'ppela'],
#  ['apple', 'pepal'],
#  ['apple', 'paple'],
#  ['apple', 'apepl'],
#  ['apple', 'lppea'],
#  ['apple', 'pepal'],
#  ['apple', 'apepl'],
#  ['apple', 'elpap'],
#  ['apple', 'elppa'],
#  ['apple', 'paepl'],
#  ['apple', 'lpape'],
#  ['apple', 'lppae'],
#  ['apple', 'leapp'],
#  ['apple', 'appel'],
#  ['apple', 'epalp'],
#  ['apple', 'plaep'],
#  ['apple', 'lappe'],
#  ['apple', 'ppeal'],
#  ['apple', 'eppal'],
#  ['apple', 'elpap'],
#  ['apple', 'apelp'],
#  ['apple', 'alppe'],
#  ['apple', 'plpae'],
#  ['apple', 'lapep'],
#  ['apple', 'paepl'],
#  ['apple', 'ppeal'],
#  ['apple', 'leppa'],
#  ['apple', 'ppela'],
#  ['apple', 'plepa'],
#  ['apple', 'plaep'],
#  ['apple', 'elpap'],
#  ['apple', 'lpaep'],
#  ['apple', 'aeppl'],
#  ['apple', 'palep'],
#  ['apple', 'elppa'],
#  ['apple', 'eaplp'],
#  ['apple', 'pelap'],
#  ['apple', 'lepap'],
#  ['apple', 'eppla'],
#  ['apple', 'pplae'],
#  ['apple', 'pepla'],
#  ['apple', 'epapl'],
#  ['apple', 'eaplp'],
#  ['apple', 'plpea'],
#  ['apple', 'aelpp'],
#  ['apple', 'palpe'],
#  ['apple', 'lpaep'],
#  ['apple', 'lppae'],
#  ['apple', 'leppa'],
#  ['apple', 'plaep'],
#  ['apple', 'lpaep'],
#  ['apple', 'epapl'],
#  ['apple', 'leppa'],
#  ['apple', 'lepap'],
#  ['apple', 'leapp'],
#  ['apple', 'ppela'],
#  ['apple', 'alppe'],
#  ['apple', 'ppela'],
#  ['apple', 'aplep'],
#  ['apple', 'epapl'],
#  ['apple', 'plpea'],
#  ['apple', 'plape'],
#  ['elapp', 'apple'],
#  ['elapp', 'eppla'],
#  ['elapp', 'plepa'],
#  ['elapp', 'eppla'],
#  ['elapp', 'pplae'],
#  ['elapp', 'laepp'],
#  ['elapp', 'lpape'],
#  ['elapp', 'palpe'],
#  ['elapp', 'aeplp'],
#  ['elapp', 'lpape'],
#  ['elapp', 'apepl'],
#  ['elapp', 'pplae'],
#  ['elapp', 'papel'],
#  ['elapp', 'lppea'],
#  ['elapp', 'pealp'],
#  ['elapp', 'ppela'],
#  ['elapp', 'eppal'],
#  ['elapp', 'apple'],
#  ['elapp', 'apepl'],
#  ['elapp', 'paelp'],
#  ['elapp', 'eplap'],
#  ['elapp', 'eappl'],
#  ['elapp', 'lppea'],
#  ['elapp', 'epapl'],
#  ['elapp', 'epapl'],
#  ['elapp', 'paple'],
#  ['elapp', 'leapp'],
#  ['elapp', 'leapp'],
#  ['elapp', 'eappl'],
#  ['elapp', 'ealpp'],
#  ['elapp', 'ppeal'],
#  ['elapp', 'palpe'],
#  ['elapp', 'aplep'],
#  ['elapp', 'lpeap'],
#  ['elapp', 'pplae'],
#  ['elapp', 'lpaep'],
#  ['elapp', 'alpep'],
#  ['elapp', 'lppae'],
#  ['elapp', 'ppela'],
#  ['elapp', 'pepal'],
#  ['elapp', 'paple'],
#  ['elapp', 'apepl'],
#  ['elapp', 'lppea'],
#  ['elapp', 'pepal'],
#  ['elapp', 'apepl'],
#  ['elapp', 'elpap'],
#  ['elapp', 'elppa'],
#  ['elapp', 'paepl'],
#  ['elapp', 'lpape'],
#  ['elapp', 'lppae'],
#  ['elapp', 'leapp'],
#  ['elapp', 'appel'],
#  ['elapp', 'epalp'],
#  ['elapp', 'plaep'],
#  ['elapp', 'lappe'],
#  ['elapp', 'ppeal'],
#  ['elapp', 'eppal'],
#  ['elapp', 'elpap'],
#  ['elapp', 'apelp'],
#  ['elapp', 'alppe'],
#  ['elapp', 'plpae'],
#  ['elapp', 'lapep'],
#  ['elapp', 'paepl'],
#  ['elapp', 'ppeal'],
#  ['elapp', 'leppa'],
#  ['elapp', 'ppela'],
#  ['elapp', 'plepa'],
#  ['elapp', 'plaep'],
#  ['elapp', 'elpap'],
#  ['elapp', 'lpaep'],
#  ['elapp', 'aeppl'],
#  ['elapp', 'palep'],
#  ['elapp', 'elppa'],
#  ['elapp', 'eaplp'],
#  ['elapp', 'pelap'],
#  ['elapp', 'lepap'],
#  ['elapp', 'eppla'],
#  ['elapp', 'pplae'],
#  ['elapp', 'pepla'],
#  ['elapp', 'epapl'],
#  ['elapp', 'eaplp'],
#  ['elapp', 'plpea'],
#  ['elapp', 'aelpp'],
#  ['elapp', 'palpe'],
#  ['elapp', 'lpaep'],
#  ['elapp', 'lppae'],
#  ['elapp', 'leppa'],
#  ['elapp', 'plaep'],
#  ['elapp', 'lpaep'],
#  ['elapp', 'epapl'],
#  ['elapp', 'leppa'],
#  ['elapp', 'lepap'],
#  ['elapp', 'leapp'],
#  ['elapp', 'ppela'],
#  ['elapp', 'alppe'],
#  ['elapp', 'ppela'],
#  ['elapp', 'aplep'],
#  ['elapp', 'epapl'],
#  ['elapp', 'plpea'],
#  ['elapp', 'plape'],
#  ['eppla', 'apple'],
#  ['eppla', 'elapp'],
#  ['eppla', 'plepa'],
#  ['eppla', 'eppla'],
#  ['eppla', 'pplae'],
#  ['eppla', 'laepp'],
#  ['eppla', 'lpape'],
#  ['eppla', 'palpe'],
#  ['eppla', 'aeplp'],
#  ['eppla', 'lpape'],
#  ['eppla', 'apepl'],
#  ['eppla', 'pplae'],
#  ['eppla', 'papel'],
#  ['eppla', 'lppea'],
#  ['eppla', 'pealp'],
#  ['eppla', 'ppela'],
#  ['eppla', 'eppal'],
#  ['eppla', 'apple'],
#  ['eppla', 'apepl'],
#  ['eppla', 'paelp'],
#  ['eppla', 'eplap'],
#  ['eppla', 'eappl'],
#  ['eppla', 'lppea'],
#  ['eppla', 'epapl'],
#  ['eppla', 'epapl'],
#  ['eppla', 'paple'],
#  ['eppla', 'leapp'],
#  ['eppla', 'leapp'],
#  ['eppla', 'eappl'],
#  ['eppla', 'ealpp'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'palpe'],
#  ['eppla', 'aplep'],
#  ['eppla', 'lpeap'],
#  ['eppla', 'pplae'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'alpep'],
#  ['eppla', 'lppae'],
#  ['eppla', 'ppela'],
#  ['eppla', 'pepal'],
#  ['eppla', 'paple'],
#  ['eppla', 'apepl'],
#  ['eppla', 'lppea'],
#  ['eppla', 'pepal'],
#  ['eppla', 'apepl'],
#  ['eppla', 'elpap'],
#  ['eppla', 'elppa'],
#  ['eppla', 'paepl'],
#  ['eppla', 'lpape'],
#  ['eppla', 'lppae'],
#  ['eppla', 'leapp'],
#  ['eppla', 'appel'],
#  ['eppla', 'epalp'],
#  ['eppla', 'plaep'],
#  ['eppla', 'lappe'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'eppal'],
#  ['eppla', 'elpap'],
#  ['eppla', 'apelp'],
#  ['eppla', 'alppe'],
#  ['eppla', 'plpae'],
#  ['eppla', 'lapep'],
#  ['eppla', 'paepl'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'leppa'],
#  ['eppla', 'ppela'],
#  ['eppla', 'plepa'],
#  ['eppla', 'plaep'],
#  ['eppla', 'elpap'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'aeppl'],
#  ['eppla', 'palep'],
#  ['eppla', 'elppa'],
#  ['eppla', 'eaplp'],
#  ['eppla', 'pelap'],
#  ['eppla', 'lepap'],
#  ['eppla', 'eppla'],
#  ['eppla', 'pplae'],
#  ['eppla', 'pepla'],
#  ['eppla', 'epapl'],
#  ['eppla', 'eaplp'],
#  ['eppla', 'plpea'],
#  ['eppla', 'aelpp'],
#  ['eppla', 'palpe'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'lppae'],
#  ['eppla', 'leppa'],
#  ['eppla', 'plaep'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'epapl'],
#  ['eppla', 'leppa'],
#  ['eppla', 'lepap'],
#  ['eppla', 'leapp'],
#  ['eppla', 'ppela'],
#  ['eppla', 'alppe'],
#  ['eppla', 'ppela'],
#  ['eppla', 'aplep'],
#  ['eppla', 'epapl'],
#  ['eppla', 'plpea'],
#  ['eppla', 'plape'],
#  ['plepa', 'apple'],
#  ['plepa', 'elapp'],
#  ['plepa', 'eppla'],
#  ['plepa', 'eppla'],
#  ['plepa', 'pplae'],
#  ['plepa', 'laepp'],
#  ['plepa', 'lpape'],
#  ['plepa', 'palpe'],
#  ['plepa', 'aeplp'],
#  ['plepa', 'lpape'],
#  ['plepa', 'apepl'],
#  ['plepa', 'pplae'],
#  ['plepa', 'papel'],
#  ['plepa', 'lppea'],
#  ['plepa', 'pealp'],
#  ['plepa', 'ppela'],
#  ['plepa', 'eppal'],
#  ['plepa', 'apple'],
#  ['plepa', 'apepl'],
#  ['plepa', 'paelp'],
#  ['plepa', 'eplap'],
#  ['plepa', 'eappl'],
#  ['plepa', 'lppea'],
#  ['plepa', 'epapl'],
#  ['plepa', 'epapl'],
#  ['plepa', 'paple'],
#  ['plepa', 'leapp'],
#  ['plepa', 'leapp'],
#  ['plepa', 'eappl'],
#  ['plepa', 'ealpp'],
#  ['plepa', 'ppeal'],
#  ['plepa', 'palpe'],
#  ['plepa', 'aplep'],
#  ['plepa', 'lpeap'],
#  ['plepa', 'pplae'],
#  ['plepa', 'lpaep'],
#  ['plepa', 'alpep'],
#  ['plepa', 'lppae'],
#  ['plepa', 'ppela'],
#  ['plepa', 'pepal'],
#  ['plepa', 'paple'],
#  ['plepa', 'apepl'],
#  ['plepa', 'lppea'],
#  ['plepa', 'pepal'],
#  ['plepa', 'apepl'],
#  ['plepa', 'elpap'],
#  ['plepa', 'elppa'],
#  ['plepa', 'paepl'],
#  ['plepa', 'lpape'],
#  ['plepa', 'lppae'],
#  ['plepa', 'leapp'],
#  ['plepa', 'appel'],
#  ['plepa', 'epalp'],
#  ['plepa', 'plaep'],
#  ['plepa', 'lappe'],
#  ['plepa', 'ppeal'],
#  ['plepa', 'eppal'],
#  ['plepa', 'elpap'],
#  ['plepa', 'apelp'],
#  ['plepa', 'alppe'],
#  ['plepa', 'plpae'],
#  ['plepa', 'lapep'],
#  ['plepa', 'paepl'],
#  ['plepa', 'ppeal'],
#  ['plepa', 'leppa'],
#  ['plepa', 'ppela'],
#  ['plepa', 'plepa'],
#  ['plepa', 'plaep'],
#  ['plepa', 'elpap'],
#  ['plepa', 'lpaep'],
#  ['plepa', 'aeppl'],
#  ['plepa', 'palep'],
#  ['plepa', 'elppa'],
#  ['plepa', 'eaplp'],
#  ['plepa', 'pelap'],
#  ['plepa', 'lepap'],
#  ['plepa', 'eppla'],
#  ['plepa', 'pplae'],
#  ['plepa', 'pepla'],
#  ['plepa', 'epapl'],
#  ['plepa', 'eaplp'],
#  ['plepa', 'plpea'],
#  ['plepa', 'aelpp'],
#  ['plepa', 'palpe'],
#  ['plepa', 'lpaep'],
#  ['plepa', 'lppae'],
#  ['plepa', 'leppa'],
#  ['plepa', 'plaep'],
#  ['plepa', 'lpaep'],
#  ['plepa', 'epapl'],
#  ['plepa', 'leppa'],
#  ['plepa', 'lepap'],
#  ['plepa', 'leapp'],
#  ['plepa', 'ppela'],
#  ['plepa', 'alppe'],
#  ['plepa', 'ppela'],
#  ['plepa', 'aplep'],
#  ['plepa', 'epapl'],
#  ['plepa', 'plpea'],
#  ['plepa', 'plape'],
#  ['eppla', 'apple'],
#  ['eppla', 'elapp'],
#  ['eppla', 'eppla'],
#  ['eppla', 'plepa'],
#  ['eppla', 'pplae'],
#  ['eppla', 'laepp'],
#  ['eppla', 'lpape'],
#  ['eppla', 'palpe'],
#  ['eppla', 'aeplp'],
#  ['eppla', 'lpape'],
#  ['eppla', 'apepl'],
#  ['eppla', 'pplae'],
#  ['eppla', 'papel'],
#  ['eppla', 'lppea'],
#  ['eppla', 'pealp'],
#  ['eppla', 'ppela'],
#  ['eppla', 'eppal'],
#  ['eppla', 'apple'],
#  ['eppla', 'apepl'],
#  ['eppla', 'paelp'],
#  ['eppla', 'eplap'],
#  ['eppla', 'eappl'],
#  ['eppla', 'lppea'],
#  ['eppla', 'epapl'],
#  ['eppla', 'epapl'],
#  ['eppla', 'paple'],
#  ['eppla', 'leapp'],
#  ['eppla', 'leapp'],
#  ['eppla', 'eappl'],
#  ['eppla', 'ealpp'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'palpe'],
#  ['eppla', 'aplep'],
#  ['eppla', 'lpeap'],
#  ['eppla', 'pplae'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'alpep'],
#  ['eppla', 'lppae'],
#  ['eppla', 'ppela'],
#  ['eppla', 'pepal'],
#  ['eppla', 'paple'],
#  ['eppla', 'apepl'],
#  ['eppla', 'lppea'],
#  ['eppla', 'pepal'],
#  ['eppla', 'apepl'],
#  ['eppla', 'elpap'],
#  ['eppla', 'elppa'],
#  ['eppla', 'paepl'],
#  ['eppla', 'lpape'],
#  ['eppla', 'lppae'],
#  ['eppla', 'leapp'],
#  ['eppla', 'appel'],
#  ['eppla', 'epalp'],
#  ['eppla', 'plaep'],
#  ['eppla', 'lappe'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'eppal'],
#  ['eppla', 'elpap'],
#  ['eppla', 'apelp'],
#  ['eppla', 'alppe'],
#  ['eppla', 'plpae'],
#  ['eppla', 'lapep'],
#  ['eppla', 'paepl'],
#  ['eppla', 'ppeal'],
#  ['eppla', 'leppa'],
#  ['eppla', 'ppela'],
#  ['eppla', 'plepa'],
#  ['eppla', 'plaep'],
#  ['eppla', 'elpap'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'aeppl'],
#  ['eppla', 'palep'],
#  ['eppla', 'elppa'],
#  ['eppla', 'eaplp'],
#  ['eppla', 'pelap'],
#  ['eppla', 'lepap'],
#  ['eppla', 'eppla'],
#  ['eppla', 'pplae'],
#  ['eppla', 'pepla'],
#  ['eppla', 'epapl'],
#  ['eppla', 'eaplp'],
#  ['eppla', 'plpea'],
#  ['eppla', 'aelpp'],
#  ['eppla', 'palpe'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'lppae'],
#  ['eppla', 'leppa'],
#  ['eppla', 'plaep'],
#  ['eppla', 'lpaep'],
#  ['eppla', 'epapl'],
#  ['eppla', 'leppa'],
#  ['eppla', 'lepap'],
#  ['eppla', 'leapp'],
#  ['eppla', 'ppela'],
#  ['eppla', 'alppe'],
#  ['eppla', 'ppela'],
#  ['eppla', 'aplep'],
#  ['eppla', 'epapl'],
#  ['eppla', 'plpea'],
#  ['eppla', 'plape'],
#  ['pplae', 'apple'],
#  ['pplae', 'elapp'],
#  ['pplae', 'eppla'],
#  ['pplae', 'plepa'],
#  ['pplae', 'eppla'],
#  ['pplae', 'laepp'],
#  ['pplae', 'lpape'],
#  ['pplae', 'palpe'],
#  ['pplae', 'aeplp'],
#  ['pplae', 'lpape'],
#  ['pplae', 'apepl'],
#  ['pplae', 'pplae'],
#  ['pplae', 'papel'],
#  ['pplae', 'lppea'],
#  ['pplae', 'pealp'],
#  ['pplae', 'ppela'],
#  ['pplae', 'eppal'],
#  ['pplae', 'apple'],
#  ['pplae', 'apepl'],
#  ['pplae', 'paelp'],
#  ['pplae', 'eplap'],
#  ['pplae', 'eappl'],
#  ['pplae', 'lppea'],
#  ['pplae', 'epapl'],
#  ['pplae', 'epapl'],
#  ['pplae', 'paple'],
#  ['pplae', 'leapp'],
#  ['pplae', 'leapp'],
#  ['pplae', 'eappl'],
#  ['pplae', 'ealpp'],
#  ['pplae', 'ppeal'],
#  ['pplae', 'palpe'],
#  ['pplae', 'aplep'],
#  ['pplae', 'lpeap'],
#  ['pplae', 'pplae'],
#  ['pplae', 'lpaep'],
#  ['pplae', 'alpep'],
#  ['pplae', 'lppae'],
#  ['pplae', 'ppela'],
#  ['pplae', 'pepal'],
#  ['pplae', 'paple'],
#  ['pplae', 'apepl'],
#  ['pplae', 'lppea'],
#  ['pplae', 'pepal'],
#  ['pplae', 'apepl'],
#  ['pplae', 'elpap'],
#  ['pplae', 'elppa'],
#  ['pplae', 'paepl'],
#  ['pplae', 'lpape'],
#  ['pplae', 'lppae'],
#  ['pplae', 'leapp'],
#  ['pplae', 'appel'],
#  ['pplae', 'epalp'],
#  ['pplae', 'plaep'],
#  ['pplae', 'lappe'],
#  ['pplae', 'ppeal'],
#  ['pplae', 'eppal'],
#  ['pplae', 'elpap'],
#  ['pplae', 'apelp'],
#  ['pplae', 'alppe'],
#  ['pplae', 'plpae'],
#  ['pplae', 'lapep'],
#  ['pplae', 'paepl'],
#  ['pplae', 'ppeal'],
#  ['pplae', 'leppa'],
#  ['pplae', 'ppela'],
#  ['pplae', 'plepa'],
#  ['pplae', 'plaep'],
#  ['pplae', 'elpap'],
#  ['pplae', 'lpaep'],
#  ['pplae', 'aeppl'],
#  ['pplae', 'palep'],
#  ['pplae', 'elppa'],
#  ['pplae', 'eaplp'],
#  ['pplae', 'pelap'],
#  ['pplae', 'lepap'],
#  ['pplae', 'eppla'],
#  ['pplae', 'pplae'],
#  ['pplae', 'pepla'],
#  ['pplae', 'epapl'],
#  ['pplae', 'eaplp'],
#  ['pplae', 'plpea'],
#  ['pplae', 'aelpp'],
#  ['pplae', 'palpe'],
#  ['pplae', 'lpaep'],
#  ['pplae', 'lppae'],
#  ['pplae', 'leppa'],
#  ['pplae', 'plaep'],
#  ['pplae', 'lpaep'],
#  ['pplae', 'epapl'],
#  ['pplae', 'leppa'],
#  ['pplae', 'lepap'],
#  ['pplae', 'leapp'],
#  ['pplae', 'ppela'],
#  ['pplae', 'alppe'],
#  ['pplae', 'ppela'],
#  ['pplae', 'aplep'],
#  ['pplae', 'epapl'],
#  ['pplae', 'plpea'],
#  ['pplae', 'plape'],
#  ['laepp', 'apple'],
#  ['laepp', 'elapp'],
#  ['laepp', 'eppla'],
#  ['laepp', 'plepa'],
#  ['laepp', 'eppla'],
#  ['laepp', 'pplae'],
#  ['laepp', 'lpape'],
#  ['laepp', 'palpe'],
#  ['laepp', 'aeplp'],
#  ['laepp', 'lpape'],
#  ['laepp', 'apepl'],
#  ['laepp', 'pplae'],
#  ['laepp', 'papel'],
#  ['laepp', 'lppea'],
#  ['laepp', 'pealp'],
#  ['laepp', 'ppela'],
#  ['laepp', 'eppal'],
#  ['laepp', 'apple'],
#  ['laepp', 'apepl'],
#  ['laepp', 'paelp'],
#  ['laepp', 'eplap'],
#  ['laepp', 'eappl'],
#  ['laepp', 'lppea'],
#  ['laepp', 'epapl'],
#  ['laepp', 'epapl'],
#  ['laepp', 'paple'],
#  ['laepp', 'leapp'],
#  ['laepp', 'leapp'],
#  ['laepp', 'eappl'],
#  ['laepp', 'ealpp'],
#  ['laepp', 'ppeal'],
#  ['laepp', 'palpe'],
#  ['laepp', 'aplep'],
#  ['laepp', 'lpeap'],
#  ['laepp', 'pplae'],
#  ['laepp', 'lpaep'],
#  ['laepp', 'alpep'],
#  ['laepp', 'lppae'],
#  ['laepp', 'ppela'],
#  ['laepp', 'pepal'],
#  ['laepp', 'paple'],
#  ['laepp', 'apepl'],
#  ['laepp', 'lppea'],
#  ['laepp', 'pepal'],
#  ['laepp', 'apepl'],
#  ['laepp', 'elpap'],
#  ['laepp', 'elppa'],
#  ['laepp', 'paepl'],
#  ['laepp', 'lpape'],
#  ['laepp', 'lppae'],
#  ['laepp', 'leapp'],
#  ['laepp', 'appel'],
#  ['laepp', 'epalp'],
#  ['laepp', 'plaep'],
#  ['laepp', 'lappe'],
#  ['laepp', 'ppeal'],
#  ['laepp', 'eppal'],
#  ['laepp', 'elpap'],
#  ['laepp', 'apelp'],
#  ['laepp', 'alppe'],
#  ['laepp', 'plpae'],
#  ['laepp', 'lapep'],
#  ['laepp', 'paepl'],
#  ['laepp', 'ppeal'],
#  ['laepp', 'leppa'],
#  ['laepp', 'ppela'],
#  ['laepp', 'plepa'],
#  ['laepp', 'plaep'],
#  ['laepp', 'elpap'],
#  ['laepp', 'lpaep'],
#  ['laepp', 'aeppl'],
#  ['laepp', 'palep'],
#  ['laepp', 'elppa'],
#  ['laepp', 'eaplp'],
#  ['laepp', 'pelap'],
#  ['laepp', 'lepap'],
#  ['laepp', 'eppla'],
#  ['laepp', 'pplae'],
#  ['laepp', 'pepla'],
#  ['laepp', 'epapl'],
#  ['laepp', 'eaplp'],
#  ['laepp', 'plpea'],
#  ['laepp', 'aelpp'],
#  ['laepp', 'palpe'],
#  ['laepp', 'lpaep'],
#  ['laepp', 'lppae'],
#  ['laepp', 'leppa'],
#  ['laepp', 'plaep'],
#  ['laepp', 'lpaep'],
#  ['laepp', 'epapl'],
#  ['laepp', 'leppa'],
#  ['laepp', 'lepap'],
#  ['laepp', 'leapp'],
#  ['laepp', 'ppela'],
#  ['laepp', 'alppe'],
#  ['laepp', 'ppela'],
#  ['laepp', 'aplep'],
#  ['laepp', 'epapl'],
#  ['laepp', 'plpea'],
#  ['laepp', 'plape'],
#  ['lpape', 'apple'],
#  ['lpape', 'elapp'],
#  ['lpape', 'eppla'],
#  ['lpape', 'plepa'],
#  ['lpape', 'eppla'],
#  ['lpape', 'pplae'],
#  ['lpape', 'laepp'],
#  ['lpape', 'palpe'],
#  ['lpape', 'aeplp'],
#  ['lpape', 'lpape'],
#  ['lpape', 'apepl'],
#  ['lpape', 'pplae'],
#  ['lpape', 'papel'],
#  ['lpape', 'lppea'],
#  ['lpape', 'pealp'],
#  ['lpape', 'ppela'],
#  ['lpape', 'eppal'],
#  ['lpape', 'apple'],
#  ['lpape', 'apepl'],
#  ['lpape', 'paelp'],
#  ['lpape', 'eplap'],
#  ['lpape', 'eappl'],
#  ['lpape', 'lppea'],
#  ['lpape', 'epapl'],
#  ['lpape', 'epapl'],
#  ['lpape', 'paple'],
#  ['lpape', 'leapp'],
#  ['lpape', 'leapp'],
#  ['lpape', 'eappl'],
#  ['lpape', 'ealpp'],
#  ['lpape', 'ppeal'],
#  ['lpape', 'palpe'],
#  ['lpape', 'aplep'],
#  ['lpape', 'lpeap'],
#  ['lpape', 'pplae'],
#  ['lpape', 'lpaep'],
#  ['lpape', 'alpep'],
#  ['lpape', 'lppae'],
#  ['lpape', 'ppela'],
#  ['lpape', 'pepal'],
#  ['lpape', 'paple'],
#  ['lpape', 'apepl'],
#  ['lpape', 'lppea'],
#  ['lpape', 'pepal'],
#  ['lpape', 'apepl'],
#  ['lpape', 'elpap'],
#  ['lpape', 'elppa'],
#  ['lpape', 'paepl'],
#  ['lpape', 'lpape'],
#  ['lpape', 'lppae'],
#  ['lpape', 'leapp'],
#  ['lpape', 'appel'],
#  ['lpape', 'epalp'],
#  ['lpape', 'plaep'],
#  ['lpape', 'lappe'],
#  ['lpape', 'ppeal'],
#  ['lpape', 'eppal'],
#  ['lpape', 'elpap'],
#  ['lpape', 'apelp'],
#  ['lpape', 'alppe'],
#  ['lpape', 'plpae'],
#  ['lpape', 'lapep'],
#  ['lpape', 'paepl'],
#  ['lpape', 'ppeal'],
#  ['lpape', 'leppa'],
#  ['lpape', 'ppela'],
#  ['lpape', 'plepa'],
#  ['lpape', 'plaep'],
#  ['lpape', 'elpap'],
#  ['lpape', 'lpaep'],
#  ['lpape', 'aeppl'],
#  ['lpape', 'palep'],
#  ['lpape', 'elppa'],
#  ['lpape', 'eaplp'],
#  ['lpape', 'pelap'],
#  ['lpape', 'lepap'],
#  ['lpape', 'eppla'],
#  ['lpape', 'pplae'],
#  ['lpape', 'pepla'],
#  ['lpape', 'epapl'],
#  ['lpape', 'eaplp'],
#  ['lpape', 'plpea'],
#  ['lpape', 'aelpp'],
#  ['lpape', 'palpe'],
#  ['lpape', 'lpaep'],
#  ['lpape', 'lppae'],
#  ['lpape', 'leppa'],
#  ['lpape', 'plaep'],
#  ['lpape', 'lpaep'],
#  ['lpape', 'epapl'],
#  ['lpape', 'leppa'],
#  ['lpape', 'lepap'],
#  ['lpape', 'leapp'],
#  ['lpape', 'ppela'],
#  ['lpape', 'alppe'],
#  ['lpape', 'ppela'],
#  ['lpape', 'aplep'],
#  ['lpape', 'epapl'],
#  ['lpape', 'plpea'],
#  ['lpape', 'plape'],
#  ['palpe', 'apple'],
#  ['palpe', 'elapp'],
#  ['palpe', 'eppla'],
#  ['palpe', 'plepa'],
#  ['palpe', 'eppla'],
#  ['palpe', 'pplae'],
#  ['palpe', 'laepp'],
#  ['palpe', 'lpape'],
#  ['palpe', 'aeplp'],
#  ['palpe', 'lpape'],
#  ['palpe', 'apepl'],
#  ['palpe', 'pplae'],
#  ['palpe', 'papel'],
#  ['palpe', 'lppea'],
#  ['palpe', 'pealp'],
#  ['palpe', 'ppela'],
#  ['palpe', 'eppal'],
#  ['palpe', 'apple'],
#  ['palpe', 'apepl'],
#  ['palpe', 'paelp'],
#  ['palpe', 'eplap'],
#  ['palpe', 'eappl'],
#  ['palpe', 'lppea'],
#  ['palpe', 'epapl'],
#  ['palpe', 'epapl'],
#  ['palpe', 'paple'],
#  ['palpe', 'leapp'],
#  ['palpe', 'leapp'],
#  ['palpe', 'eappl'],
#  ['palpe', 'ealpp'],
#  ['palpe', 'ppeal'],
#  ['palpe', 'palpe'],
#  ['palpe', 'aplep'],
#  ['palpe', 'lpeap'],
#  ['palpe', 'pplae'],
#  ['palpe', 'lpaep'],
#  ['palpe', 'alpep'],
#  ['palpe', 'lppae'],
#  ['palpe', 'ppela'],
#  ['palpe', 'pepal'],
#  ['palpe', 'paple'],
#  ['palpe', 'apepl'],
#  ['palpe', 'lppea'],
#  ['palpe', 'pepal'],
#  ['palpe', 'apepl'],
#  ['palpe', 'elpap'],
#  ['palpe', 'elppa'],
#  ['palpe', 'paepl'],
#  ['palpe', 'lpape'],
#  ['palpe', 'lppae'],
#  ['palpe', 'leapp'],
#  ['palpe', 'appel'],
#  ['palpe', 'epalp'],
#  ['palpe', 'plaep'],
#  ['palpe', 'lappe'],
#  ['palpe', 'ppeal'],
#  ['palpe', 'eppal'],
#  ['palpe', 'elpap'],
#  ['palpe', 'apelp'],
#  ['palpe', 'alppe'],
#  ['palpe', 'plpae'],
#  ['palpe', 'lapep'],
#  ['palpe', 'paepl'],
#  ['palpe', 'ppeal'],
#  ['palpe', 'leppa'],
#  ['palpe', 'ppela'],
#  ['palpe', 'plepa'],
#  ['palpe', 'plaep'],
#  ['palpe', 'elpap'],
#  ['palpe', 'lpaep'],
#  ['palpe', 'aeppl'],
#  ['palpe', 'palep'],
#  ['palpe', 'elppa'],
#  ['palpe', 'eaplp'],
#  ['palpe', 'pelap'],
#  ['palpe', 'lepap'],
#  ['palpe', 'eppla'],
#  ['palpe', 'pplae'],
#  ['palpe', 'pepla'],
#  ['palpe', 'epapl'],
#  ['palpe', 'eaplp'],
#  ['palpe', 'plpea'],
#  ['palpe', 'aelpp'],
#  ['palpe', 'palpe'],
#  ['palpe', 'lpaep'],
#  ['palpe', 'lppae'],
#  ['palpe', 'leppa'],
#  ['palpe', 'plaep'],
#  ['palpe', 'lpaep'],
#  ['palpe', 'epapl'],
#  ['palpe', 'leppa'],
#  ['palpe', 'lepap'],
#  ['palpe', 'leapp'],
#  ['palpe', 'ppela'],
#  ['palpe', 'alppe'],
#  ['palpe', 'ppela'],
#  ['palpe', 'aplep'],
#  ['palpe', 'epapl'],
#  ['palpe', 'plpea'],
#  ['palpe', 'plape'],
#  ['aeplp', 'apple'],
#  ['aeplp', 'elapp'],
#  ['aeplp', 'eppla'],
#  ['aeplp', 'plepa'],
#  ['aeplp', 'eppla'],
#  ['aeplp', 'pplae'],
#  ['aeplp', 'laepp'],
#  ['aeplp', 'lpape'],
#  ['aeplp', 'palpe'],
#  ['aeplp', 'lpape'],
#  ['aeplp', 'apepl'],
#  ['aeplp', 'pplae'],
#  ['aeplp', 'papel'],
#  ['aeplp', 'lppea'],
#  ['aeplp', 'pealp'],
#  ['aeplp', 'ppela'],
#  ['aeplp', 'eppal'],
#  ['aeplp', 'apple'],
#  ['aeplp', 'apepl'],
#  ['aeplp', 'paelp'],
#  ['aeplp', 'eplap'],
#  ['aeplp', 'eappl'],
#  ['aeplp', 'lppea'],
#  ['aeplp', 'epapl'],
#  ['aeplp', 'epapl'],
#  ['aeplp', 'paple'],
#  ['aeplp', 'leapp'],
#  ['aeplp', 'leapp'],
#  ['aeplp', 'eappl'],
#  ['aeplp', 'ealpp'],
#  ['aeplp', 'ppeal'],
#  ['aeplp', 'palpe'],
#  ['aeplp', 'aplep'],
#  ['aeplp', 'lpeap'],
#  ['aeplp', 'pplae'],
#  ['aeplp', 'lpaep'],
#  ['aeplp', 'alpep'],
#  ['aeplp', 'lppae'],
#  ['aeplp', 'ppela'],
#  ['aeplp', 'pepal'],
#  ['aeplp', 'paple'],
#  ['aeplp', 'apepl'],
#  ['aeplp', 'lppea'],
#  ['aeplp', 'pepal'],
#  ['aeplp', 'apepl'],
#  ['aeplp', 'elpap'],
#  ['aeplp', 'elppa'],
#  ['aeplp', 'paepl'],
#  ['aeplp', 'lpape'],
#  ['aeplp', 'lppae'],
#  ['aeplp', 'leapp'],
#  ['aeplp', 'appel'],
#  ['aeplp', 'epalp'],
#  ['aeplp', 'plaep'],
#  ['aeplp', 'lappe'],
#  ['aeplp', 'ppeal'],
#  ['aeplp', 'eppal'],
#  ['aeplp', 'elpap'],
#  ['aeplp', 'apelp'],
#  ['aeplp', 'alppe'],
#  ['aeplp', 'plpae'],
#  ['aeplp', 'lapep'],
#  ['aeplp', 'paepl'],
#  ['aeplp', 'ppeal'],
#  ['aeplp', 'leppa'],
#  ['aeplp', 'ppela'],
#  ['aeplp', 'plepa'],
#  ['aeplp', 'plaep'],
#  ['aeplp', 'elpap'],
#  ['aeplp', 'lpaep'],
#  ['aeplp', 'aeppl'],
#  ['aeplp', 'palep'],
#  ['aeplp', 'elppa'],
#  ['aeplp', 'eaplp'],
#  ['aeplp', 'pelap'],
#  ['aeplp', 'lepap'],
#  ['aeplp', 'eppla'],
#  ['aeplp', 'pplae'],
#  ['aeplp', 'pepla'],
#  ['aeplp', 'epapl'],
#  ['aeplp', 'eaplp'],
#  ['aeplp', 'plpea'],
#  ['aeplp', 'aelpp'],
#  ['aeplp', 'palpe'],
#  ['aeplp', 'lpaep'],
#  ['aeplp', 'lppae'],
#  ['aeplp', 'leppa'],
#  ['aeplp', 'plaep'],
#  ['aeplp', 'lpaep'],
#  ['aeplp', 'epapl'],
#  ['aeplp', 'leppa'],
#  ['aeplp', 'lepap'],
#  ['aeplp', 'leapp'],
#  ['aeplp', 'ppela'],
#  ['aeplp', 'alppe'],
#  ['aeplp', 'ppela'],
#  ['aeplp', 'aplep'],
#  ['aeplp', 'epapl'],
#  ['aeplp', 'plpea'],
#  ['aeplp', 'plape'],
#  ...]

# %%
# Import FastText module from gensim package
from gensim.models import FastText

# Create pairs of correct and incorrect words
word_pairs = []
for word_group in words_list:
    correct_word = word_group[0]
    for incorrect_word in word_group[1:]:
        word_pairs.append([correct_word, incorrect_word])

# Train FastText model on word pairs
model = FastText(vector_size=100, window=5, min_count=0)
model.build_vocab(corpus_iterable=word_pairs)
model.train(corpus_iterable=word_pairs, total_examples=len(word_pairs), epochs=10)

# Get most similar words and similarity score to the correct word
input_word = 'plaep'  # Example input
similar_words = model.wv.most_similar(input_word, topn=5)

# Find the correct word for the input_word
correct_word = None
for word_group in words_list:
    if input_word in word_group[1:]:
        correct_word = word_group[0]
        break

if correct_word:
    similarity_score = model.wv.similarity(correct_word, input_word)
    print("Similar words:", similar_words)
    print(f"Similarity score with '{correct_word}':", similarity_score)
else:
    print("Input word not found in words_list")
# Out:
# Input word not found in words_list

# %%
# Import FastText module from gensim package
from gensim.models import FastText

# Build vocabulary from words_list
model = FastText(vector_size=100, window=5, min_count=1)
model.build_vocab(corpus_iterable=words_list)

# Train FastText model on words_list
model.train(corpus_iterable=words_list, total_examples=len(words_list), epochs=10)

# Get most similar words
input_word = 'alpe'
similar_words = model.wv.most_similar(input_word, topn=5)
print(f"Most similar words for '{input_word}':", similar_words)

# Find the correct word
correct_word = words_list[0][0]

# Check if the correct word is in the list of most similar words
found_correct_word = False
for word, similarity in similar_words:
    if word == correct_word:
        found_correct_word = True
        break

if found_correct_word:
    print(f"The correct word '{correct_word}' was found in the most similar words.")
else:
    print(f"The correct word '{correct_word}' was not found in the most similar words.")
# Out:
# Most similar words for 'alpe': [('palpe', 0.6286823749542236), ('alpep', 0.5968292951583862), ('payaap', 0.47144967317581177), ('pyaapa', 0.46989625692367554), ('ypaaap', 0.4483319818973541)]
# The correct word 'apple' was not found in the most similar words.

# %%
from gensim.models import FastText


# Train FastText model on the flattened list
model = FastText(vector_size=100, window=5, min_count=1)
model.build_vocab(corpus_iterable=word_pairs)
model.train(corpus_iterable=word_pairs, total_examples=len(word_pairs), epochs=10)

# Get most similar words for a given input
input_word = 'nan'
similar_words = model.wv.most_similar(input_word, topn=5)
print(f"Most similar words for '{input_word}':", similar_words)

# Find the correct word for the input_word
correct_word = None
for word_group in words_list:
    if input_word in word_group[1:]:
        correct_word = word_group[0]
        break

if correct_word:
    found_correct_word = False
    for word, similarity in similar_words:
        if word == correct_word:
            found_correct_word = True
            break

    if found_correct_word:
        print(f"The correct word '{correct_word}' was found in the most similar words.")
    else:
        print(f"The correct word '{correct_word}' was not found in the most similar words.")
else:
    print("Input word not found in words_list")
# Out:
# Most similar words for 'nan': [('naabna', 0.9686025381088257), ('naaabn', 0.9678683876991272), ('naaban', 0.9676371812820435), ('anaban', 0.9675046801567078), ('anbaan', 0.9668506383895874)]
# Input word not found in words_list

# %%
# Get most similar words for a given input
input_word = 'omar'
similar_words = model.wv.most_similar(input_word, topn=5)
print(f"Most similar words for '{input_word}':", similar_words)

# Take the first word from the list of most similar words
first_similar_word = similar_words[0][0]

# Find the correct word for the first_similar_word
correct_word = None
for word_group in words_list:
    if first_similar_word in word_group:
        correct_word = word_group[0]
        break

if correct_word:
    print(f"The correct word for '{input_word}' is '{correct_word}'.")
else:
    print(f"The correct word for '{input_word}' could not be found.")
# Out:
# Most similar words for 'omar': [('mnoag', 0.9290922284126282), ('mngao', 0.9203705191612244), ('goanm', 0.9183382391929626), ('oamng', 0.917656421661377), ('onmag', 0.9171356558799744)]
# The correct word for 'omar' is 'mango'.
